# %%
import pandas as pd
import plotly.graph_objects as go

# %%
cpi_df = pd.read_csv('CPIAUCSL.csv')

# %%
cpi_df['datetime'] = pd.to_datetime(cpi_df.DATE, format='%Y-%m-%d')
cpi_df
# Out:
#            DATE  CPIAUCSL   datetime
# 0    1947-01-01    21.480 1947-01-01
# 1    1947-02-01    21.620 1947-02-01
# 2    1947-03-01    22.000 1947-03-01
# 3    1947-04-01    22.000 1947-04-01
# 4    1947-05-01    21.950 1947-05-01
# ..          ...       ...        ...
# 904  2022-05-01   291.474 2022-05-01
# 905  2022-06-01   295.328 2022-06-01
# 906  2022-07-01   295.271 2022-07-01
# 907  2022-08-01   295.620 2022-08-01
# 908  2022-09-01   296.761 2022-09-01
#
# [909 rows x 3 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=cpi_df['datetime'], y=cpi_df['CPIAUCSL'], mode='lines', name='Current Market', line={'width': 3, 'color': 'darkblue'}, 
    #hovertemplate=[f" {x['change']:.1%} ({x['timestamp'].strftime('%b %d, %Y')})" for i, x in currentMarket.iterrows()]
    ))
fig.update_layout( 
    yaxis=dict(tickformat="0.2%"),
    xaxis_title = "Trading days since last peak 🠆",
    yaxis_title = "🠄 Drawdown",
    template='simple_white',
    paper_bgcolor="rgb(255,255,255)", plot_bgcolor="rgb(255,255,255)",
    legend_traceorder="reversed",
    hovermode='x unified',
    margin=dict(t=50),
    width=1200
)
fig.show()

# %%
cpi_df.dtypes
# Out:
# DATE         object
# CPIAUCSL    float64
# dtype: object

# %%
cpi_df.DATE
# Out:
# 0      1947-01-01
# 1      1947-02-01
# 2      1947-03-01
# 3      1947-04-01
# 4      1947-05-01
#           ...
# 904    2022-05-01
# 905    2022-06-01
# 906    2022-07-01
# 907    2022-08-01
# 908    2022-09-01
# Name: DATE, Length: 909, dtype: object
